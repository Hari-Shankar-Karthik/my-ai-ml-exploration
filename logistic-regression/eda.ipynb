# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('../datasets/Default.xlsx', index_col=0)
# Out:
# C:\Users\praji\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df
# Out:
#       default student      balance        income
# 1          No      No   729.526495  44361.625074
# 2          No     Yes   817.180407  12106.134700
# 3          No      No  1073.549164  31767.138947
# 4          No      No   529.250605  35704.493935
# 5          No      No   785.655883  38463.495879
# ...       ...     ...          ...           ...
# 9996       No      No   711.555020  52992.378914
# 9997       No      No   757.962918  19660.721768
# 9998       No      No   845.411989  58636.156984
# 9999       No      No  1569.009053  36669.112365
# 10000      No     Yes   200.922183  16862.952321
#
# [10000 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 1 to 10000
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   default  10000 non-null  object
#  1   student  10000 non-null  object
#  2   balance  10000 non-null  float64
#  3   income   10000 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 390.6+ KB

# %%
df['default'].unique(), df['student'].unique()
# Out:
# (array(['No', 'Yes'], dtype=object), array(['No', 'Yes'], dtype=object))

# %%
df = df.replace({'Yes': True, 'No': False})

# %%
df
# Out:
#        default  student      balance        income
# 1        False    False   729.526495  44361.625074
# 2        False     True   817.180407  12106.134700
# 3        False    False  1073.549164  31767.138947
# 4        False    False   529.250605  35704.493935
# 5        False    False   785.655883  38463.495879
# ...        ...      ...          ...           ...
# 9996     False    False   711.555020  52992.378914
# 9997     False    False   757.962918  19660.721768
# 9998     False    False   845.411989  58636.156984
# 9999     False    False  1569.009053  36669.112365
# 10000    False     True   200.922183  16862.952321
#
# [10000 rows x 4 columns]

# %%
sns.heatmap(df.corr(), annot=True, cmap='viridis')
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df, x='balance', y='default')
# Out:
# <Axes: xlabel='balance', ylabel='default'>

# %%
sample_df = pd.concat([df[~df['default']].sample(frac=.05), df[df['default']]])
sns.scatterplot(data=sample_df, x='income', y='balance', hue='default', style='default')
# Out:
# <Axes: xlabel='income', ylabel='balance'>

# %%
sns.boxplot(data=df, x='default', y='balance')
# Out:
# <Axes: xlabel='default', ylabel='balance'>
