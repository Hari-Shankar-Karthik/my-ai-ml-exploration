# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../datasets/Heart.csv', index_col=0)

# %%
df
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 1     63    1       typical     145   233    1        2    150      0
# 2     67    1  asymptomatic     160   286    0        2    108      1
# 3     67    1  asymptomatic     120   229    0        2    129      1
# 4     37    1    nonanginal     130   250    0        0    187      0
# 5     41    0    nontypical     130   204    0        2    172      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 299   45    1       typical     110   264    0        0    132      0
# 300   68    1  asymptomatic     144   193    1        0    141      0
# 301   57    1  asymptomatic     130   131    0        0    115      1
# 302   57    0    nontypical     130   236    0        2    174      0
# 303   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 1        2.3      3  0.0       fixed   No
# ...

# %%
# AIM: To make a RandomForestClassifier to predict AHD, and compare the importances of the features

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 303 entries, 1 to 303
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        303 non-null    int64
#  1   Sex        303 non-null    int64
#  2   ChestPain  303 non-null    object
#  3   RestBP     303 non-null    int64
#  4   Chol       303 non-null    int64
#  5   Fbs        303 non-null    int64
#  6   RestECG    303 non-null    int64
#  7   MaxHR      303 non-null    int64
#  8   ExAng      303 non-null    int64
#  9   Oldpeak    303 non-null    float64
#  10  Slope      303 non-null    int64
#  11  Ca         299 non-null    float64
#  12  Thal       301 non-null    object
#  13  AHD        303 non-null    object
# dtypes: float64(2), int64(9), object(3)
# memory usage: 35.5+ KB

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 297 entries, 1 to 302
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        297 non-null    int64
#  1   Sex        297 non-null    int64
#  2   ChestPain  297 non-null    object
#  3   RestBP     297 non-null    int64
#  4   Chol       297 non-null    int64
#  5   Fbs        297 non-null    int64
#  6   RestECG    297 non-null    int64
#  7   MaxHR      297 non-null    int64
#  8   ExAng      297 non-null    int64
#  9   Oldpeak    297 non-null    float64
#  10  Slope      297 non-null    int64
#  11  Ca         297 non-null    float64
#  12  Thal       297 non-null    object
#  13  AHD        297 non-null    object
# dtypes: float64(2), int64(9), object(3)
# memory usage: 34.8+ KB

# %%
df.head()
# Out:
#    Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 1   63    1       typical     145   233    1        2    150      0      2.3
# 2   67    1  asymptomatic     160   286    0        2    108      1      1.5
# 3   67    1  asymptomatic     120   229    0        2    129      1      2.6
# 4   37    1    nonanginal     130   250    0        0    187      0      3.5
# 5   41    0    nontypical     130   204    0        2    172      0      1.4
#
#    Slope   Ca        Thal  AHD
# 1      3  0.0       fixed   No
# 2      2  3.0      normal  Yes
# 3      2  2.0  reversable  Yes
# 4      3  0.0      normal   No
# 5      1  0.0      normal   No

# %%
categorical_cols = ['Sex', 'ChestPain', 'Fbs', 'RestECG', 'ExAng', 'Slope', 'Ca', 'Thal']
df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

# %%
df.head()
# Out:
#    Age  RestBP  Chol  MaxHR  Oldpeak  AHD  Sex_1  ChestPain_nonanginal  \
# 1   63     145   233    150      2.3   No   True                 False
# 2   67     160   286    108      1.5  Yes   True                 False
# 3   67     120   229    129      2.6  Yes   True                 False
# 4   37     130   250    187      3.5   No   True                  True
# 5   41     130   204    172      1.4   No  False                 False
#
#    ChestPain_nontypical  ChestPain_typical  ...  RestECG_1  RestECG_2  \
# 1                 False               True  ...      False       True
# 2                 False              False  ...      False       True
# 3                 False              False  ...      False       True
# 4                 False              False  ...      False      False
# 5                  True              False  ...      False       True
#
#    ExAng_1  Slope_2  Slope_3  Ca_1.0  Ca_2.0  Ca_3.0  Thal_normal  \
# ...

# %%
X, y = df.drop(columns='AHD'), df['AHD']

# %%
y.value_counts()
# Out:
# AHD
# No     160
# Yes    137
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=42)

# %%
# NOTE: Modified from the original
rfc = RandomForestClassifier(criterion='log_loss', max_features='log2')
param_grid = {
    'n_estimators': np.arange(400, 600, 10),
}

# %%
grid = GridSearchCV(rfc, param_grid, scoring='accuracy', verbose=3)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END ..................n_estimators=400;, score=0.690 total time=   0.5s
# [CV 2/5] END ..................n_estimators=400;, score=0.833 total time=   0.5s
# [CV 3/5] END ..................n_estimators=400;, score=0.780 total time=   0.5s
# [CV 4/5] END ..................n_estimators=400;, score=0.780 total time=   0.5s
# [CV 5/5] END ..................n_estimators=400;, score=0.732 total time=   0.5s
# [CV 1/5] END ..................n_estimators=410;, score=0.690 total time=   0.6s
# [CV 2/5] END ..................n_estimators=410;, score=0.833 total time=   0.6s
# [CV 3/5] END ..................n_estimators=410;, score=0.756 total time=   0.5s
# [CV 4/5] END ..................n_estimators=410;, score=0.756 total time=   0.5s
# [CV 5/5] END ..................n_estimators=410;, score=0.707 total time=   0.5s
# [CV 1/5] END ..................n_estimators=420;, score=0.714 total time=   0.5s
# ...

# %%
grid.best_params_
# Out:
# {'n_estimators': 580}

# %%
y_pred = grid.predict(X_test)

# %%
from sklearn.metrics import classification_report, ConfusionMatrixDisplay, RocCurveDisplay

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.88      0.90      0.89        49
#          Yes       0.88      0.85      0.86        41
#
#     accuracy                           0.88        90
#    macro avg       0.88      0.88      0.88        90
# weighted avg       0.88      0.88      0.88        90

# %%
ConfusionMatrixDisplay.from_estimator(grid, X_test, y_test)

# %%
RocCurveDisplay.from_estimator(grid, X_test, y_test)

# %%
plt.figure(dpi=200)
feature_importances = pd.DataFrame({
    'Feature': grid.feature_names_in_, 
    'Importance': grid.best_estimator_.feature_importances_
}).sort_values(by='Importance')
sns.barplot(feature_importances, x='Importance', y='Feature')
# Out:
# <Axes: xlabel='Importance', ylabel='Feature'>
